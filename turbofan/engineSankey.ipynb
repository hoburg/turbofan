# %%
# Imports 
"SP Implementation of the TASOPT engine model"
from gpkit import Model, Variable, SignomialsEnabled, units, Vectorize, SignomialEquality
from gpkit.constraints.tight import Tight as TCS
from gpkit.small_scripts import mag
from gpkit.interactive.sankey import Sankey
import numpy as np

#import substitution files
from get_737800_subs import get_737800_subs
from get_d82_subs import get_D82_subs
from cfm56_subs import get_cfm56_subs
from get_ge90_subs import get_ge90_subs

# importing turbofan
from engine_validation import *

# importing
# Out:
# ​

# %%
# Running standard test
"""
Test the cfm56 engine model
"""
with Vectorize(2):
    state = TestState()

Engine.Ttmax = False
engine = Engine(0, True, 2, state, 0)

mission = TestMissionCFM(engine)

substitutions = get_cfm56_subs()

m = Model((10*engine.engineP.thrustP['TSFC'][0]+engine.engineP.thrustP['TSFC'][1]), [engine, mission], substitutions)
m.substitutions.update(substitutions)
sol = m.localsolve(verbosity = 2)
# Out:
# Beginning signomial solve.
# Using solver 'mosek_cli'
# Solving for 249 variables.
# Solving took 0.194 seconds.
# Using solver 'mosek_cli'
# Solving for 249 variables.
# Solving took 0.201 seconds.
# Using solver 'mosek_cli'
# Solving for 249 variables.
# Solving took 0.188 seconds.
# Using solver 'mosek_cli'
# Solving for 249 variables.
# Solving took 0.171 seconds.
# Using solver 'mosek_cli'
# Solving for 249 variables.
# Solving took 0.189 seconds.
# Using solver 'mosek_cli'
# Solving for 249 variables.
# Solving took 0.149 seconds.
# Using solver 'mosek_cli'
# Solving for 249 variables.
# Solving took 0.157 seconds.
# Using solver 'mosek_cli'
# Solving for 249 variables.
# Solving took 0.216 seconds.
# Using solver 'mosek_cli'
# Solving for 249 variables.
# Solving took 0.16 seconds.
# Using solver 'mosek_cli'
# Solving for 249 variables.
# Solving took 0.169 seconds.
# Solving took 10 GP solves and 3.94 seconds.
# Warning: Constraint [-0.5*C_{p_{c}}_Engine/Combustor**-1*u_{4.1}_Engine/EnginePerformance/CombustorPerformance_(1,)**2 + ... >= T_{4.1}_Engine/EnginePerformance/CombustorPerformance_(1,) [K]...] is not tight because the left hand side evaluated to 1382.06172405 kelvin but the right hand side evaluated to 1351.88744176 kelvin (Allowable error: 0.0001%, Actual error: 2.2%)
#
# Warning: Constraint [2*h_{t_8}_Engine/EnginePerformance/ThrustPerformance_(0,) [J/kg]... >= 2*h_{8}_Engine/EnginePerformance/ThrustPerformance_(0,) + u_{8}_Engine/EnginePerformance/ThrustPerfo...] is not tight because the left hand side evaluated to 591115.778885 joule / kilogram but the right hand side evaluated to 591111.945235 meter ** 2 / second ** 2 (Allowable error: 0.0001%, Actual error: 0.00065%)
#
# Warning: Constraint [2*h_{t_8}_Engine/EnginePerformance/ThrustPerformance_(1,) [J/kg]... >= 2*h_{8}_Engine/EnginePerformance/ThrustPerformance_(1,) + u_{8}_Engine/EnginePerformance/ThrustPerfo...] is not tight because the left hand side evaluated to 591115.778885 joule / kilogram but the right hand side evaluated to 591111.945235 meter ** 2 / second ** 2 (Allowable error: 0.0001%, Actual error: 0.00065%)
#
# Warning: Constraint [2*h_{t_6}_Engine/EnginePerformance/ThrustPerformance_(0,) [J/kg]... >= 2*h_6_Engine/EnginePerformance/ThrustPerformance_(0,) + u_{6}_Engine/EnginePerformance/ThrustPerform...] is not tight because the left hand side evaluated to 964222.330751 joule / kilogram but the right hand side evaluated to 964220.450155 meter ** 2 / second ** 2 (Allowable error: 0.0001%, Actual error: 0.0002%)
#
# Warning: Constraint [2*h_{t_6}_Engine/EnginePerformance/ThrustPerformance_(1,) [J/kg]... >= 2*h_6_Engine/EnginePerformance/ThrustPerformance_(1,) + u_{6}_Engine/EnginePerformance/ThrustPerform...] is not tight because the left hand side evaluated to 1088942.04349 joule / kilogram but the right hand side evaluated to 1088945.36618 meter ** 2 / second ** 2 (Allowable error: 0.0001%, Actual error: 0.00031%)
#
# Warning: Constraint [F_{6}_Engine/EnginePerformance/ThrustPerformance_(0,) + F_{8}_Engine/EnginePerformance/ThrustPerform... >= F_Engine/EnginePerformance/ThrustPerformance_(0,) [N]...] is not tight because the left hand side evaluated to 24184.8924878 newton but the right hand side evaluated to 24184.0837624 newton (Allowable error: 0.0001%, Actual error: 0.0033%)
#
# Warning: Constraint [F_{6}_Engine/EnginePerformance/ThrustPerformance_(1,) + F_{8}_Engine/EnginePerformance/ThrustPerform... >= F_Engine/EnginePerformance/ThrustPerformance_(1,) [N]...] is not tight because the left hand side evaluated to 26232.9462676 newton but the right hand side evaluated to 26232.3851273 newton (Allowable error: 0.0001%, Actual error: 0.0021%)
#
# Warning: Constraint [-C_{p_{fuel}_Engine/Combustor*T_{t_f}_Engine/Combustor*f_Engine/EnginePerformance/CombustorPerforman... <= \eta_{B}_Engine/Combustor*f_Engine/EnginePerformance/CombustorPerformance_(1,)*h_{f}_Engine/Combusto...] is not tight because the left hand side evaluated to 771337.697438 joule / kilogram but the right hand side evaluated to 0.771344400267 megajoule / kilogram (Allowable error: 0.0001%, Actual error: 0.00032%)
#
# Warning: Constraint [-\alpha_c_Engine/Combustor*h_{t_4}_Engine/EnginePerformance/CombustorPerformance_(0,) + \alpha_c_Eng... >= fp1_Engine/EnginePerformance/CombustorPerformance_(0,)*h_{t_{4.1}}_Engine/EnginePerformance/Combusto...] is not tight because the left hand side evaluated to 1601743.22857 joule / kilogram but the right hand side evaluated to 1601740.47041 joule / kilogram (Allowable error: 0.0001%, Actual error: 0.00014%)
#
# Warning: Constraint [-\alpha_c_Engine/Combustor*h_{t_4}_Engine/EnginePerformance/CombustorPerformance_(1,) + \alpha_c_Eng... >= fp1_Engine/EnginePerformance/CombustorPerformance_(1,)*h_{t_{4.1}}_Engine/EnginePerformance/Combusto...] is not tight because the left hand side evaluated to 1712924.48684 joule / kilogram but the right hand side evaluated to 1712929.05362 joule / kilogram (Allowable error: 0.0001%, Actual error: 0.00022%)
#
# Warning: Constraint [-M_{takeoff}_Engine/EngineConstants*\eta_{HPshaft}_Engine/Turbine*f_Engine/EnginePerformance/Combust... >= -h_{t_{2.5}}_Engine/EnginePerformance/CompressorPerformance_(0,) + h_{t_3}_Engine/EnginePerformance/...] is not tight because the left hand side evaluated to 493539.550681 joule / kilogram but the right hand side evaluated to 493536.384162 joule / kilogram (Allowable error: 0.0001%, Actual error: 0.00017%)
#
# Warning: Constraint [-M_{takeoff}_Engine/EngineConstants*\eta_{HPshaft}_Engine/Turbine*f_Engine/EnginePerformance/Combust... >= -h_{t_{2.5}}_Engine/EnginePerformance/CompressorPerformance_(1,) + h_{t_3}_Engine/EnginePerformance/...] is not tight because the left hand side evaluated to 527799.810747 joule / kilogram but the right hand side evaluated to 527797.478897 joule / kilogram (Allowable error: 0.0001%, Actual error: 0.00012%)

# %%
print sol.summary()
# Out:
# Cost
# ----
#  7.335 [1/hr]
#
# Free Variables
# --------------
#                   | Engine
#        W_{engine} : 2.32e+04                [N]     Weight of a Single Turbofan Engine
#           d_{LPC} : 0.3957                  [m]     LPC Diameter
#             d_{f} : 1.593                   [m]     Fan Diameter
#          F_{spec} : [ 2.42e+04  2.62e+04 ]  [N]     Specified Total Thrust
#               OPR : [ 60.9      69.1     ]          Overall Pressure Ratio
#
#                   | Engine/EnginePerformance/CombustorPerformance
#            M_{4a} : [ 0.103     0.103    ]          User Specified Station 4a Mach #
#            P_{4a} : [ 2.05e+03  2.33e+03 ]  [kPa]   Static Pressure at Station 4a (4a)
#           P_{t_4} : [ 2.04e+03  2.32e+03 ]  [kPa]   Stagnation Pressure at the Combustor Exit (4)
#       P_{t_{4.1}} : [ 2.05e+03  2.13e+03 ]  [kPa]   Stagnation Pressure at the Turbine Inlet (4.1)
#           T_{4.1} : [ 1.29e+03  1.35e+03 ]  [K]     Static Temperature at the Turbine Inlet (4.1)
#           T_{t_4} : [ 1.42e+03  1.52e+03 ]  [K]     Combustor Exit (Station 4) Stagnation Temperature
#       T_{t_{4.1}} : [ 1.29e+03  1.38e+03 ]  [K]     Stagnation Temperature at the Turbine Inlet (4.1)
#                 f : [ 0.0173    0.0192   ]          Fuel Air Mass Flow Fraction
#               fp1 : [ 1.02      1.02     ]          f + 1
#           h_{t_4} : [ 1.73e+06  1.85e+06 ]  [J/kg]  Stagnation Enthalpy at the Combustor Exit (4)
#       h_{t_{4.1}} : [ 1.57e+06  1.68e+06 ]  [J/kg]  Stagnation Enthalpy at the Turbine Inlet (4.1)
#               u_c : [ 0.749     0.775    ]  [m/s]   Cooling Airflow Speed at Station 4a
#           u_{4.1} : [ 3.24      3.35     ]  [m/s]   Flow Velocity at Station 4.1
#            u_{4a} : [ 74.9      77.5     ]  [m/s]   Flow Velocity at Station 4a
#
#                   | Engine/EnginePerformance/CompressorPerformance
#         P_{T_{2}} : [ 35.6      35.6     ]  [kPa]   Stagnation Pressure at the Fan Inlet (2)
#           P_{t_0} : [ 36.4      36.4     ]  [kPa]   Free Stream Stagnation Pressure
#           P_{t_3} : [ 2.17e+03  2.46e+03 ]  [kPa]   Stagnation Pressure at the HPC Exit (3)
#           P_{t_7} : [ 61.3      61.3     ]  [kPa]   Stagnation Pressure at the Fan Nozzle Exit (7)
#       P_{t_{1.8}} : [ 35.6      35.6     ]  [kPa]   Stagnation Pressure at the Diffuser Exit (1.8)
#       P_{t_{2.1}} : [ 62.5      62.5     ]  [kPa]   Stagnation Pressure at the Fan Exit (2.1)
#       P_{t_{2.5}} : [ 200       200      ]  [kPa]   Stagnation Pressure at the LPC Exit (2.5)
#         T_{T_{2}} : [ 246       246      ]  [K]     Stagnation Temperature at the Fan Inlet (2)
#           T_{t_0} : [ 246       246      ]  [K]     Free Stream Stagnation Temperature
#           T_{t_3} : [ 831       863      ]  [K]     Stagnation Temperature at the HPC Exit (3)
#           T_{t_7} : [ 294       294      ]  [K]     Stagnation Temperature at the Fan Nozzle Exit (7)
#       T_{t_{1.8}} : [ 246       246      ]  [K]     Stagnation Temperature at the Diffuser Exit (1.8)
#       T_{t_{2.1}} : [ 294       294      ]  [K]     Stagnation Temperature at the Fan Exit (2.1)
#       T_{t_{2.5}} : [ 417       417      ]  [K]     Stagnation Temperature at the LPC Exit (2.5)
#           \pi_{f} : [ 1.75      1.75     ]          Fan Pressure Ratio
#          \pi_{hc} : [ 10.9      12.3     ]          HPC Pressure Ratio
#          \pi_{lc} : [ 3.2       3.2      ]          LPC Pressure Ratio
#                c1 : [ 1.13      1.13     ]          Constant in Stagnation Eqn
#         h_{T_{2}} : [ 2.47e+05  2.47e+05 ]  [J/kg]  Stagnation Enthalpy at the Fan Inlet (2)
#           h_{t_0} : [ 2.47e+05  2.47e+05 ]  [J/kg]  Free Stream Stagnation Enthalpy
#           h_{t_3} : [ 9.14e+05  9.48e+05 ]  [J/kg]  Stagnation Enthalpy at the HPC Exit (3)
#           h_{t_7} : [ 2.95e+05  2.95e+05 ]  [J/kg]  Stagnation Enthalpy at the Fan Nozzle Exit (7)
#       h_{t_{1.8}} : [ 2.47e+05  2.47e+05 ]  [J/kg]  Stagnation Enthalpy at the Diffuser Exit (1.8)
#       h_{t_{2.1}} : [ 2.95e+05  2.95e+05 ]  [J/kg]  Stagnation Enthalpy at the Fan Exit (2.1)
#       h_{t_{2.5}} : [ 4.2e+05   4.2e+05  ]  [J/kg]  Stagnation Enthalpy at the LPC Exit (2.5)
#        hold_{2.5} : [ 1.06      1.06     ]          1+(gamma-1)/2 * M_2.5**2
#          hold_{2} : [ 1.07      1.07     ]          1+(gamma-1)/2 * M_2**2
#
#                   | Engine/EnginePerformance/FanMapPerformance
#             N_{f} : [ 1.1       1.1      ]          Fan Speed
#             m_{f} : [ 354       354      ]  [kg/s]  Fan Corrected Mass Flow
#        m_{tild_f} : [ 1.06      1.06     ]          Fan Normalized Mass Flow
#
#                   | Engine/EnginePerformance/HPCMapPerformance
#             N_{2} : [ 1.03      1.06     ]          HPC Speed
#            m_{hc} : [ 16.1      16.1     ]  [kg/s]  HPC Corrected Mass Flow
#     m_{tild_{hc}} : [ 1.21      1.21     ]          HPC Normalized Mass Flow
#
#                   | Engine/EnginePerformance/LPCMapPerformance
#             N_{1} : [ 1.1       1.1      ]          LPC Speed
#            m_{lc} : [ 69.3      69.3     ]  [kg/s]  LPC Corrected Mass Flow
#       m_{tild_lc} : [ 1.66      1.66     ]          LPC Normalized Mass Flow
#
#                   | Engine/EnginePerformance/SizingPerformance
#               M_2 : [ 0.6       0.6      ]          Fan Face/LPC Face Axial Mach Number
#               M_5 : [ 0.477     0.432    ]          Station 5 Mach Number
#               M_7 : [ 0.666     0.666    ]          Station 7 Mach Number
#           M_{2.5} : [ 0.6       0.6      ]          HPC Face Axial Mach Number
#           P_{2.5} : [ 158       158      ]  [kPa]   Static Air Pressure at HPC Face
#             P_{2} : [ 28        28       ]  [kPa]   Air Static Pressure at Fan Face
#             P_{5} : [ 35.9      41.9     ]  [kPa]   Core Exhaust Static Pressure (5)
#             P_{7} : [ 37.4      37.4     ]  [kPa]   Fan Exhaust Static Pressure (7)
#           T_{2.5} : [ 392       392      ]  [K]     Static Air Temperature at HPC Face
#             T_{2} : [ 230       230      ]  [K]     Air Static Temperature at Fan Face
#             T_{5} : [ 410       454      ]  [K]     Static Temperature at the Turbine Nozzle Exit (5)
#             T_{7} : [ 255       255      ]  [K]     Static Temperature at the Fan Nozzle Exit (7)
#            \rho_5 : [ 0.305     0.321    ]  [kg/m³] Air Static Density at Core Exhaust Exit (5)
#            \rho_7 : [ 0.51      0.51     ]  [kg/m³] Air Static Density at Fam Exhaust Exit (7)
#        \rho_{2.5} : [ 1.4       1.4      ]  [kg/m³] Static Air Density at HPC Face
#          \rho_{2} : [ 0.424     0.424    ]  [kg/m³] Air Static Density at Fan Face
#             a_{5} : [ 404       425      ]  [m/s]   Speed of Sound at Station 5
#             a_{7} : [ 320       320      ]  [m/s]   Speed of Sound at Station 7
#           h_{2.5} : [ 4.31e+05  4.31e+05 ]  [J/kg]  Static Enthalpy at the LPC Exit (2.5)
#             h_{2} : [ 2.31e+05  2.31e+05 ]  [J/kg]  Static Enthalpy at the Fan Inlet (2)
#         m_{total} : [ 173       173      ]  [kg/s]  Total Engine Mass Flux
#           u_{2.5} : [ 239       239      ]  [m/s]   Air Speed at HPC Face
#             u_{2} : [ 175       175      ]  [m/s]   Air Speed at Fan Face
#             u_{5} : [ 193       183      ]  [m/s]   Station 5 Exhaust Velocity
#             u_{7} : [ 213       213      ]  [m/s]   Station 7 Exhaust Velocity
#
#                   | Engine/EnginePerformance/ThrustPerformance
#                 F : [ 2.42e+04  2.62e+04 ]  [N]     Total Thrust
#             F_{6} : [ 5.73e+03  7.77e+03 ]  [N]     Core Thrust
#             F_{8} : [ 1.85e+04  1.85e+04 ]  [N]     Fan Thrust
#            F_{sp} : [ 0.507     0.55     ]          Specific Net Thrust
#            I_{sp} : [ 5.41e+03  5.27e+03 ]  [s]     Specific Impulse
#             P_{6} : [ 23.8      23.8     ]  [kPa]   Core Exhaust Static Pressure
#             P_{8} : [ 23.8      23.8     ]  [kPa]   Fan Exhaust Static Pressure
#           P_{t_6} : [ 58        72.6     ]  [kPa]   Core Exhaust Stagnation Pressure
#           P_{t_8} : [ 61.3      61.3     ]  [kPa]   Fan Exhaust Stagnation Pressure
#              TSFC : [ 0.665     0.683    ]  [1/hr]  Thrust Specific Fuel Consumption
#             T_{6} : [ 366       388      ]  [K]     Core Exhaust Static Temperature (6)
#             T_{8} : [ 225       225      ]  [K]     Fan Exhaust Sttic Temperature (8)
#           T_{t_6} : [ 469       529      ]  [K]     Core Exhaust Stagnation Temperature (6)
#           T_{t_8} : [ 294       294      ]  [K]     Fan Exhaust Stagnation Temperature (8)
#            \alpha : [ 5.1       5.1      ]          By Pass Ratio
#       \alpha_{+1} : [ 6.1       6.1      ]          1 plus BPR
#               h_6 : [ 3.76e+05  3.99e+05 ]  [J/kg]  Core Exhasut Static Enthalpy
#             h_{8} : [ 2.26e+05  2.26e+05 ]  [J/kg]  Fan Exhasut Static Enthalpy
#           h_{t_6} : [ 4.82e+05  5.44e+05 ]  [J/kg]  Core Exhaust Stagnation Enthalpy
#           h_{t_8} : [ 2.96e+05  2.96e+05 ]  [J/kg]  Fan Exhaust Stagnation Enthalpy
#              hold : [ 6.1       6.1      ]          unecessary hold var
#          m_{core} : [ 26.4      26.4     ]  [kg/s]  Core Mass Flow
#           m_{fan} : [ 135       135      ]  [kg/s]  Fan Mass Flow
#             u_{6} : [ 460       539      ]  [m/s]   Core Exhaust Velocity
#             u_{8} : [ 374       374      ]  [m/s]   Fan Exhaust Velocity
#
#                   | Engine/EnginePerformance/TurbinePerformance
#           P_{t_5} : [ 58        72.6     ]  [kPa]   Stagnation Pressure at the Turbine Nozzle Exit (5)
#       P_{t_{4.5}} : [ 395       409      ]  [kPa]   Stagnation Pressure at the HPT Exit (4.5)
#       P_{t_{4.9}} : [ 59.1      74.1     ]  [kPa]   Stagnation Pressure at the HPTExit (49)
#           T_{t_5} : [ 469       529      ]  [K]     Stagnation Temperature at the Turbine Nozzle Exit (5)
#       T_{t_{4.5}} : [ 821       877      ]  [K]     Stagnation Temperature at the HPT Exit (4.5)
#       T_{t_{4.9}} : [ 469       529      ]  [K]     Stagnation Temperature at the HPT Exit (49)
#         \pi_{HPT} : [ 0.192     0.192    ]          HPT Pressure Ratio
#         \pi_{LPT} : [ 0.15      0.181    ]          LPT Pressure Ratio
#           h_{t_5} : [ 5.55e+05  6.26e+05 ]  [J/kg]  Stagnation Enthalpy at the Turbine Nozzle Exit (5)
#       h_{t_{4.5}} : [ 1.05e+06  1.12e+06 ]  [J/kg]  Stagnation Enthalpy at the HPT Exit (4.5)
#       h_{t_{4.9}} : [ 5.55e+05  6.26e+05 ]  [J/kg]  Stagnation Enthalpy at the HPT Exit (49)
#
#                   | Engine/FanMap
# \bar{m}_{fan_{D}} : 334.5                   [kg/s]  Fan On-Design Corrected Mass Flow
#
#                   | Engine/HPCMap
#          m_{hc_D} : 13.31                   [kg/s]  On Design HPC Corrected Mass Flow
#
#                   | Engine/LPCMap
#          m_{lc_D} : 41.79                   [kg/s]  On Design LPC Corrected Mass Flow
#
#                   | Engine/Sizing
#           A_{2.5} : 0.07872                 [m²]    HPC Area
#             A_{2} : 1.813                   [m²]    Fan Area
#             A_{5} : 0.4357                  [m²]    Core Exhaust Nozzle Area
#             A_{7} : 1.237                   [m²]    Fan Exhaust Nozzle Area
#         m_{coreD} : 26.88                   [kg/s]  Estimated on Design Mass Flow
#           m_{htD} : 2.681                   [kg/s]  Design HPT Corrected Mass Flow (see B.225)
#           m_{ltD} : 11.09                   [kg/s]  Design LPT Corrected Mass Flow (see B.226)
#
#                   | TestState
#                 M : [ 0.8       0.8      ]          Mach Number
#           P_{atm} : [ 23.8      23.8     ]  [kPa]   air pressure
#           T_{atm} : [ 218       218      ]  [K]     air temperature
#                 V : [ 460       460      ]  [kt]    Aircraft Flight Speed
#                 a : [ 296       296      ]  [m/s]   Speed of Sound
#
# Most Sensitive
# --------------
#                | Engine/Combustor
#      C_{p_{c}} : -1.2  Cp Value for Fuel/Air Mix in Combustor
#
#                | Engine/Compressor
#        \pi_{d} : -1.2  Diffuser Pressure Ratio
#
#                | Engine/EngineConstants
#    M_{takeoff} : -1.4  1 Minus Percent mass flow loss for de-ice, pressurization, etc.
#
#                | Engine/Turbine
# \eta_{HPshaft} : -1.2  Power Transmission Efficiency of High Pressure Shaft, Smears in Losses for Electrical Power
#     C_{p_{t2}} : +1.1  Cp Value for Combustion Products in LP Turbine

# %%
#Sankey(m).sorted_by("constraints", 4)
Sankey(m).diagram(m['T_{t_{4.1}}'])
# Out:
# Ⓐ adds -1.17 to the overall sensitivity of T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)
# Ⓐ is h_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,) = C_{p_{c}}_Engine/Combustor*T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)
#
# Ⓑ adds -1.01 to the overall sensitivity of T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)
# Ⓑ is -0.5*C_{p_{c}}_Engine/Combustor**-1*u_{4.1}_Engine/EnginePerformance/CombustorPerformance_(0,)**2 + T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,) >= T_{4.1}_Engine/EnginePerformance/CombustorPerformance_(0,)
#
# Ⓒ adds +1.01 to the overall sensitivity of T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)
# Ⓒ is P_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,) = P_{4a}_Engine/EnginePerformance/CombustorPerformance_(0,)*T_{4.1}_Engine/EnginePerformance/CombustorPerformance_(0,)**4.2*T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)**-4.2
#
# Ⓓ adds +1.22 to the overall sensitivity of T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)
# Ⓓ is \pi_{HPT}_Engine/EnginePerformance/TurbinePerformance_(0,) = T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)**-3.6*T_{t_{4.5}}_Engine/EnginePerformance/TurbinePerformance_(0,)**3.6
#
# Ⓔ adds -0.0481 to the overall sensitivity of T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)
# Ⓔ is m_{htD}_Engine/Sizing = M_{takeoff}_Engine/EngineConstants*P_{t_{2.5}}_Engine/EnginePerformance/CompressorPerformance_(0,)*P_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)**-1*T_{t_{2.5}}_Engine/EnginePerformance/CompressorPerformance_(0,)**-0.5*T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)**0.5*fp1_Engine/EnginePerformance/CombustorPerformance_(0,)*m_{hc}_Engine/EnginePerformance/HPCMapPerformance_(0,)
#
# Ⓕ adds +0.0182 to the overall sensitivity of T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)
# Ⓕ is h_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,) = C_{p_{c}}_Engine/Combustor*T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)
#
# Ⓖ adds -5.35e-09 to the overall sensitivity of T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)
# Ⓖ is -0.5*C_{p_{c}}_Engine/Combustor**-1*u_{4.1}_Engine/EnginePerformance/CombustorPerformance_(1,)**2 + T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,) >= T_{4.1}_Engine/EnginePerformance/CombustorPerformance_(1,)
#
# Ⓗ adds +5.34e-09 to the overall sensitivity of T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)
# Ⓗ is P_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,) = P_{4a}_Engine/EnginePerformance/CombustorPerformance_(1,)*T_{4.1}_Engine/EnginePerformance/CombustorPerformance_(1,)**4.2*T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)**-4.2
#
# Ⓘ adds -0.0212 to the overall sensitivity of T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)
# Ⓘ is \pi_{HPT}_Engine/EnginePerformance/TurbinePerformance_(1,) = T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)**-3.6*T_{t_{4.5}}_Engine/EnginePerformance/TurbinePerformance_(1,)**3.6
#
# Ⓙ adds +0.00292 to the overall sensitivity of T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)
# Ⓙ is m_{htD}_Engine/Sizing = M_{takeoff}_Engine/EngineConstants*P_{t_{2.5}}_Engine/EnginePerformance/CompressorPerformance_(1,)*P_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)**-1*T_{t_{2.5}}_Engine/EnginePerformance/CompressorPerformance_(1,)**-0.5*T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)**0.5*fp1_Engine/EnginePerformance/CombustorPerformance_(1,)*m_{hc}_Engine/EnginePerformance/HPCMapPerformance_(1,)
# SankeyWidget(layout=Layout(height=u'400', width=u'900'), links=[{'color': '#cfcfcf', 'source': 'T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)', 'target': 'Model', 'value': 1.2162188935830185e-05}, {'color': '#59ade4', 'source': 'Model', 'target': u'\u24ba', 'value': 0.04811485}, {'color': '#cfcfcf', 'source': 'Model', 'target': u'\u24bf', 'value': 0.0029244805}, {'color': '#FA3333', 'source': 'Model', 'target': u'\u24bb', 'value': 0.01824113}, {'color': '#59ade4', 'source': 'Model', 'target': u'\u24b7', 'value': 1.0062033503280001}, {'color': '#FA3333', 'source': 'Model', 'target': u'\u24b9', 'value': 1.2162188935830185}, {'color': '#59ade4', 'source': 'Model', 'target': u'\u24be', 'value': 0.021165616837635216}, {'color': '#FA3333', 'source': 'Model', 'target': u'\u24b8', 'value': 1.0061997217252399}, {'color': '#59ade4', 'source': 'Model', 'target': u'\u24b6', 'value': 1.168101}, {'color': '#cfcfcf', 'source': 'Model', 'target': u'\u24bd', 'value': 1.2162188935830185e-05}, {'color': '#cfcfcf', 'source': 'T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)', 'target': 'Model', 'value': 1.2162188935830185e-05}, {'color': '#cfcfcf', 'source': 'Model', 'target': u'\u24bc', 'value': 1.2162188935830185e-05}], margins={'top': 0, 'right': 55, 'left': 120, 'bottom': 0}, nodes=[{'id': 'T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(0,)', 'title': u'T_{t_{4.1}}_(0,) [K]'}, {'id': 'T_{t_{4.1}}_Engine/EnginePerformance/CombustorPerformance_(1,)', 'title': u'T_{t_{4.1}}_(1,) [K]'}, {'id': u'\u24bc'}, {'id': u'\u24b7'}, {'id': u'\u24b6'}, {'id': u'\u24b9'}, {'id': u'\u24b8'}, {'id': 'Model'}, {'id': u'\u24ba'}, {'id': u'\u24bd'}, {'id': u'\u24bb'}, {'id': u'\u24bf'}, {'id': u'\u24be'}])
